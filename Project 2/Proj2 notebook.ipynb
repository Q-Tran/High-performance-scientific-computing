# %%
x  = loadtxt('x.txt')
t = loadtxt('t.txt')
y = loadtxt('y.txt')

# %%
plot(t,x); xlabel('time'); ylabel('x(t)'); title('$x(t)$')

# %%
plot(t,y); xlabel('time'); ylabel('y(t)'); title('$y(t)$')

# %%
plot(x,y); xlabel('time'); ylabel('y(t)'); title('$y(t)$')
