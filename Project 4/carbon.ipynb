# %% [raw]
# Van Tran
# Math 3316
# 11/26/15

# %% [markdown]
# Load all data

# %%
Temp = loadtxt('temp.txt')
Time = loadtxt('time.txt')
C2mm = loadtxt('C2mm.txt')
C4mm = loadtxt('C4mm.txt')
C2mm800 = loadtxt('C2mm_800K.txt')
C2mm900 = loadtxt('C2mm_900K.txt')
C2mm1000 = loadtxt('C2mm_1000.txt')
C2mm1100 = loadtxt('C2mm_24hour.txt')
C2mm1200 = loadtxt('C2mm_1200.txt')
C4mm800 = loadtxt('C4mm_800K.txt')
C4mm900 = loadtxt('C4mm_900K.txt')
C4mm1000 = loadtxt('C4mm_1000.txt')
C4mm1100 = loadtxt('C4mm_1100.txt')
C4mm1200 = loadtxt('C4mm_1200.txt')

# %%
figure()
imshow(C2mm)
colorbar(orientation='horizontal')
title('C2mm Contour plot')

# %%
figure()
imshow(C4mm)
colorbar(orientation='horizontal')
title('C4mm Contour plot')

# %%
plot(Time, C2mm800, Time, C2mm900, Time, C2mm1000, Time, C2mm1100, Time, C2mm1200)
title('C2mm Temps vs Time')
xlabel('Time')
ylabel('C2mmT')
legend(('$C2mm800$', '$C2mm900$', '$C2mm1000$', '$C2mm1100$', '$C2mm1200$'))

# %%
plot(Time, C4mm800, Time, C4mm900, Time, C4mm1000, Time, C4mm1100, Time, C4mm1200)
title('C4mm Temps vs Time')
xlabel('Time')
ylabel('C4mmT')
legend(('$C4mm800$', '$C4mm900$', '$C4mm1000$', '$C4mm1100$', '$C4mm1200$'))
